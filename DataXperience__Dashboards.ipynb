# %% [markdown]
# # Visualización, Dashboards y Cuadernos para Ciencia de Datos

# %% [markdown]
# ## Introducción

# %% [markdown]
# En el dinámico campo de la ciencia de datos, la capacidad de transformar datos crudos en información comprensible y accionable es fundamental. Este cuaderno interactivo de Google Colab está diseñado para ser una guía práctica y pedagógica que te sumergirá en tres pilares esenciales del análisis de datos: la visualización efectiva, la creación de dashboards inteligentes y el uso de cuadernos interactivos como herramientas de trabajo. Exploraremos cómo estas herramientas no solo nos permiten entender mejor nuestros datos, sino también comunicar nuestros hallazgos de manera clara y convincente.
#
# A lo largo de este cuaderno, utilizaremos un conjunto de datos público para ilustrar cada concepto con ejemplos prácticos en Python y R, permitiéndote aplicar y experimentar con las técnicas aprendidas. ¡Prepárate para potenciar tus habilidades en ciencia de datos y convertirte en un narrador de datos excepcional!

# %% [markdown]
# ## 1. Visualización de Datos: El Poder de los Gráficos en Ciencia de Datos

# %% [markdown]
# En el análisis de datos, "una imagen vale más que mil palabras". La visualización de datos es el arte y la ciencia de presentar la información de manera gráfica para facilitar su comprensión, identificar patrones, tendencias y valores atípicos que de otra forma serían difíciles de discernir en tablas de números. Elegir el gráfico correcto es fundamental para comunicar eficazmente tus hallazgos.
#
# #

# %% [markdown]
# ## Tipos de Gráficos Esenciales y sus Usos

# %% [markdown]
# Cada tipo de gráfico está diseñado para resaltar diferentes aspectos de tus datos:
#
# *   **Diagrama de Barras:** Representa datos categóricos mediante barras rectangulares. La altura de cada barra indica la frecuencia o el valor asociado a esa categoría. Es ideal para comparar elementos independientes como países, productos o colores.
#
# *   **Histogramas:** Muestran la distribución de frecuencia de una variable numérica. Dividen los datos en "contenedores" (bins) y cuentan cuántas observaciones caen en cada contenedor, mostrando la forma general de la distribución de los datos, su asimetría o curtosis. Son fundamentales para comparar distribuciones.
#
# *   **Diagramas de Cajas y Bigotes (Box Plots):** Son excelentes para visualizar la distribución de una variable numérica. Muestran la mediana, los cuartiles (Q1 y Q3), el rango intercuartílico (IQR) y, crucialmente, los posibles valores atípicos (outliers). Son muy útiles para comparar la distribución de una variable entre diferentes grupos.
#
# *   **Diagramas de Violín (Violin Plots):** Similares a los box-plots, pero añaden una estimación de la densidad de probabilidad (una "curva" que muestra la concentración de puntos de datos). Esto permite ver la forma de la distribución y si hay múltiples "picos" (modas). Son más informativos que los box-plots cuando la distribución es compleja.

# %% [markdown]
# ## Usar la visualización para mejorar la interpretación

# %% [markdown]
# La visualización no es solo para "hacerlo bonito"; es una herramienta analítica poderosa.
#
# *   **Claridad y Comprensión:** Un gráfico bien diseñado puede comunicar patrones complejos o grandes volúmenes de datos de forma instantánea, mucho más rápido que leer tablas.
# *   **Detección de Anomalías:** Facilita la detección de outliers gráficamente, que son puntos de datos que se desvían significativamente del patrón general. Por ejemplo, en un box plot, los outliers se muestran como puntos individuales fuera de los "bigotes".
# *   **Comparación de Distribuciones:** Permite comparar distribuciones entre diferentes grupos o categorías. Por ejemplo, puedes ver rápidamente si las ventas en la región A tienen un rango similar a las de la región B, o si las edades de tus clientes de un producto son más jóvenes que las de otro.
# *   **Identificación de Patrones y Tendencias:** Los gráficos de líneas, por ejemplo, son ideales para ver tendencias a lo largo del tiempo, mientras que los diagramas de dispersión pueden revelar relaciones entre dos variables.

# %% [markdown]
# ## Actividad Sugerida: Elige tu Gráfico

# %% [markdown]
# Imagina que estás analizando un dataset de la duración de las llamadas de un centro de atención al cliente. Quieres entender:
#
# *   La distribución general de la duración de las llamadas (¿la mayoría son cortas, largas, o hay un patrón central?).
# *   Si hay llamadas excepcionalmente largas o cortas (posibles outliers).
# *   Cómo se compara la duración de las llamadas entre los clientes nuevos y los clientes recurrentes.
#
# **Reflexiona y comparte:**
#
# ¿Qué tipo(s) de gráfico(s) usarías para cada uno de estos objetivos y por qué? ¿Cómo te ayudarían a interpretar los datos de manera más efectiva?

# %% [markdown]
# ## 2. Tableros Inteligentes: Visualiza, Analiza y Toma Acción

# %% [markdown]
# En la era del Big Data, tener acceso a información es vital, pero saber cómo interpretarla y utilizarla es lo que marca la diferencia. Aquí es donde entran los Dashboards (Paneles de Control): herramientas visuales interactivas que consolidan y presentan los datos más importantes de un vistazo. Un dashboard no es solo un conjunto de gráficos, sino una narrativa visual que permite a los usuarios monitorear el rendimiento, tomar decisiones informadas y contar historias con sus datos de manera efectiva.

# %% [markdown]
# ## Tipos de Dashboards: Estratégicos, Analíticos y Operativos

# %% [markdown]
# No todos los dashboards son iguales. Se diseñan con propósitos y audiencias diferentes en mente:
#
# *   **Estratégicos:** Orientados a la alta dirección, se centran en el rendimiento a largo plazo y la alineación con los objetivos de la empresa. Utilizan Indicadores Clave de Rendimiento (KPIs) de alto nivel y ofrecen una vista panorámica del estado de la organización.
# *   **Analíticos:** Dirigidos a analistas de datos, permiten explorar los datos en profundidad para identificar tendencias, patrones y las causas raíz de ciertos comportamientos. Son más interactivos, con capacidad para filtrar, desglosar y comparar datos.
# *   **Operativos:** Enfocados en monitorear procesos en tiempo real y alertar sobre problemas inmediatos. Son utilizados por el personal operativo para gestionar tareas diarias y garantizar el buen funcionamiento de las operaciones. Suelen mostrar datos en vivo con KPIs que requieren acción inmediata.

# %% [markdown]
# ## Elementos Clave de un Dashboard Eficaz

# %% [markdown]
# Un dashboard bien diseñado es más que la suma de sus partes. Estos son sus componentes esenciales:
#
# *   **KPIs (Key Performance Indicators):** Son las métricas cruciales que se rastrean para evaluar el rendimiento de un objetivo específico. Deben ser claros, medibles y directamente relacionados con los objetivos de negocio.
# *   **Filtros:** Permiten a los usuarios personalizar la vista de los datos para centrarse en segmentos específicos (ej. por región, fecha, producto). Esto facilita el análisis contextual y la identificación de problemas o éxitos específicos.
# *   **Interactividad:** La capacidad de un dashboard para responder a las acciones del usuario, como hacer clic en un gráfico para ver detalles, arrastrar y soltar elementos, o cambiar el tipo de visualización. La interactividad transforma un dashboard de una imagen estática a una herramienta de exploración de datos dinámica.
# *   **Visualizaciones Claras:** El uso de gráficos y tablas apropiados que comuniquen la información de manera eficiente y sin ambigüedades.
# *   **Disposición Intuitiva:** La organización de los elementos en el dashboard debe ser lógica y fácil de seguir, guiando al usuario a través de la información clave.

# %% [markdown]
# ## Ejemplo Estático e Interactivo de un Dashboard

# %% [markdown]
# Un dashboard estático es una instantánea fija de los datos en un momento dado, como una imagen. Ofrece una vista rápida pero limitada. Por otro lado, un dashboard interactivo permite al usuario manipular los datos directamente en la interfaz: seleccionar rangos de fechas, aplicar filtros por categorías, hacer clic en gráficos para ver más detalles, y mucho más. Esta interactividad es lo que lo convierte en una herramienta dinámica de exploración y descubrimiento, permitiendo al usuario "dialogar" con los datos.

# %% [markdown]
# ## Actividad Sugerida: Diseña tu Primer Mini-Dashboard

# %% [markdown]
# Imagina que eres el gerente de marketing de una tienda online y necesitas un dashboard para monitorear el rendimiento de tus campañas.
#
# **Reflexiona y comparte:**
#
# ¿Qué tipo de dashboard sería el más adecuado (estratégico, analítico, operativo) y por qué?
# Nombra al menos 3 KPIs que incluirías y justifica su importancia.
# ¿Qué elementos de interactividad (filtros, desgloses) serían esenciales para este dashboard y por qué?

# %% [markdown]
# ## 3. Cuadernos Interactivos: Tu Laboratorio Digital para Ciencia de Datos

# %% [markdown]
# En ciencia de datos, no solo importa obtener resultados: también es esencial que estos sean reproducibles, comprensibles y compartibles. Los cuadernos interactivos como Jupyter, Google Colab y RStudio son herramientas clave que combinan código, visualizaciones y texto explicativo en un mismo entorno. Son ideales para contar historias con datos, colaborar en tiempo real y documentar todo tu proceso analítico.
#
# #

# %% [markdown]
# ## Uso de Jupyter Notebooks: Un Entorno de Trabajo Versátil

# %% [markdown]
# Los Jupyter Notebooks se han convertido en el estándar de facto para la ciencia de datos debido a su flexibilidad y capacidad para contar una historia con los datos:
#
# *   **Celdas de Código:** Ejecuta fragmentos de código en lenguajes como Python, mostrando los resultados directamente debajo. Esto permite un desarrollo iterativo y depuración sencilla.
# *   **Celdas de Markdown:** Escribe explicaciones detalladas, notas, encabezados y listas utilizando el lenguaje de marcado Markdown. Esto contextualiza tu análisis y lo hace comprensible para otros.
# *   **Visualización en Línea:** Genera gráficos y tablas directamente en el cuaderno, permitiendo una visualización inmediata de tus datos y resultados.
# *   **Reproducibilidad:** Un cuaderno es un registro completo de tu proceso de análisis, desde la carga de datos hasta la visualización final, facilitando la replicación exacta de tus resultados por cualquier persona que tenga el cuaderno y el entorno adecuado.
# *   **Interactividad:** Con librerías como `ipywidgets`, puedes añadir elementos interactivos como deslizadores o botones para explorar los datos dinámicamente.

# %% [markdown]
# ## Cuadernos interactivos en la nube: Google Colab como entorno ágil y colaborativo

# %% [markdown]
# En ciencia de datos, la colaboración y el acceso rápido a recursos computacionales son tan importantes como la reproducibilidad. Aquí es donde Google Colab destaca como una solución accesible, potente y sin necesidad de instalación. Colab permite crear y compartir cuadernos interactivos directamente desde el navegador, integrando código en Python, visualizaciones, texto explicativo y celdas interactivas, todo guardado automáticamente en Google Drive.
#
# **Uso de Google Colab: Ciencia de datos en la nube, sin complicaciones**
#
# Google Colab se ha convertido en una herramienta popular para quienes buscan una experiencia similar a Jupyter, pero con beneficios adicionales como acceso gratuito a GPU/TPU y colaboración en tiempo real:
#
# *   **Celdas de Código:** Ejecuta código en Python con acceso a bibliotecas populares (como pandas, seaborn, scikit-learn) ya preinstaladas.
# *   **Texto explicativo (Markdown):** Agrega notas, títulos y descripciones para documentar tu flujo de trabajo.
# *   **Visualización integrada:** Muestra gráficos interactivos directamente bajo las celdas con bibliotecas como matplotlib y plotly.
# *   **Almacenamiento en la nube:** Todos los cambios se guardan automáticamente en Google Drive, permitiendo continuar desde cualquier dispositivo.
# *   **Colaboración en tiempo real:** Varias personas pueden editar el mismo cuaderno al estilo Google Docs, ideal para trabajo en equipo.
# *   **Interactividad:** Se pueden usar librerías como ipywidgets o conectarse a formularios externos para recolectar o visualizar datos dinámicamente.
#
# **Extensiones y ampliaciones en Colab**
#
# Aunque Colab no permite tantas personalizaciones como Jupyter local, ofrece herramientas potentes:
#
# *   **Integración con BigQuery y Google Sheets:** Ideal para análisis en entornos empresariales.
# *   **Montaje de Google Drive:** Accede a archivos fácilmente desde tu cuenta para trabajar con datos en la nube.
# *   **Conexión a GitHub:** Carga cuadernos desde repositorios públicos o privados.
#
# Colab es ideal para aprendizaje, prototipado rápido, colaboraciones en línea y experimentos que requieren acceso sencillo a recursos computacionales avanzados.

# %% [markdown]
# ## Uso de RStudio: Un entorno integral para trabajar con datos

# %% [markdown]
# RStudio combina múltiples herramientas en una sola interfaz pensada para analistas y científicos de datos:
#
# *   **Script de código R:** Ejecuta y guarda análisis paso a paso.
# *   **RMarkdown:** Combina código, texto explicativo, gráficos y resultados en un solo documento reproducible, ideal para reportes o publicaciones.
# *   **Visualización en línea:** Crea gráficos de alta calidad con ggplot2, plotly y otras bibliotecas directamente integradas.
# *   **Entorno de trabajo estructurado:** Gestión de proyectos, historial, variables activas, paquetes y archivos en una sola vista.
# *   **Soporte multilenguaje:** Aunque está centrado en R, también soporta Python y SQL para flujos híbridos.
#
# **Extensiones y herramientas en RStudio**
#
# RStudio se puede potenciar con muchas funcionalidades extra que facilitan la productividad:
#
# *   **Shiny:** Convierte tus análisis en aplicaciones web interactivas sin necesidad de saber HTML o JavaScript.
# *   **Quarto (sucesor de RMarkdown):** Publica documentos, presentaciones, dashboards y sitios web directamente desde tu código.
# *   **RStudio Connect / Posit Cloud:** Publica, comparte y automatiza reportes y apps de forma profesional.
# *   **Paquetes CRAN y Bioconductor:** Accede a miles de librerías específicas para análisis estadístico, bioinformática, econometría, etc.
#
# RStudio es ideal para análisis profundos, documentación técnica, publicaciones reproducibles y desarrollo de productos analíticos con fuerte respaldo estadístico.

# %% [markdown]
# ## Introducción a Voila y Otras Extensiones

# %% [markdown]
# La experiencia Jupyter se puede expandir y mejorar con varias herramientas:
#
# *   **Voila:** Es una herramienta que convierte cuadernos Jupyter en aplicaciones web interactivas independientes. Permite a los usuarios compartir su trabajo sin necesidad de que el receptor vea el código subyacente. Esto es ideal para crear dashboards simples o demostraciones interactivas para audiencias no técnicas.
# *   **JupyterLab:** Una interfaz de usuario de próxima generación para Project Jupyter, que ofrece un entorno de desarrollo integrado más flexible y potente, permitiendo trabajar con múltiples cuadernos, terminales y archivos de texto en una sola ventana.
# *   **Extensiones (nbextensions):** Existe una gran variedad de extensiones para Jupyter Notebooks que añaden funcionalidades útiles, como tablas de contenido automáticas, herramientas de depuración, ocultamiento de código y más, personalizando tu entorno de trabajo.

# %% [markdown]
# ## Un Cuaderno Jupyter en Acción

# %% [markdown]
# Imagina que estás presentando el análisis de ventas de un producto nuevo. En un cuaderno Jupyter, podrías tener celdas de código que cargan los datos, celdas de texto que explican la metodología, gráficos interactivos que muestran las tendencias de ventas por región y celdas de salida con resúmenes estadísticos. Todo esto, de forma secuencial y legible, lo que te permite llevar a tu audiencia a través de tu proceso de descubrimiento de insights. Si usas Voila, ¡podrías incluso transformar ese análisis en una aplicación web interactiva que los gerentes pueden explorar por sí mismos sin ver una línea de código!

# %% [markdown]
# ## Actividad Sugerida: Tu Primer Guion de Análisis

# %% [markdown]
# Piensa en un pequeño proyecto de análisis de datos que te interese (ej. analizar el clima de tu ciudad, tus gastos mensuales, etc.).
#
# **Reflexiona y comparte:**
#
# ¿Cómo estructurarías un cuaderno Jupyter para este análisis? (Piensa en las secciones de código, texto y visualizaciones).
# ¿Qué tipo de gráfico generarías y en qué celda?
# Si quisieras compartir este análisis con alguien que no sabe programar, ¿cómo te ayudaría Voila?

# %% [markdown]
# ## 4. Limpieza de Datos: Preparando el Terreno para el Análisis

# %% [markdown]
# Antes de sumergirnos en el análisis de distribuciones o aplicar técnicas de escalado, es imperativo asegurar la calidad de nuestros datos. La limpieza de datos es un paso crítico en el preprocesamiento que implica identificar y corregir errores, inconsistencias y valores faltantes en el conjunto de datos. Un dataset "sucio" puede llevar a análisis sesgados, modelos ineficaces y conclusiones erróneas. En esta sección, exploraremos algunas de las tareas de limpieza de datos más comunes utilizando nuestro dataset de ejemplo.
#
# Para este cuaderno, utilizaremos el famoso dataset del Titanic, que contiene información sobre los pasajeros del trágico viaje, incluyendo su estado de supervivencia, edad, sexo, clase de billete, etc. Este dataset es ideal para demostrar la limpieza de datos debido a la presencia de valores faltantes y la necesidad de transformaciones.

# %% [markdown]
# ## Carga del Dataset y Exploración Inicial

# %% [markdown]
# Primero, cargaremos el dataset y realizaremos una exploración inicial para entender su estructura y detectar posibles problemas. Utilizaremos `.info()` para obtener un resumen conciso del DataFrame, incluyendo el tipo de datos de cada columna y la cantidad de valores no nulos, y `.describe()` para obtener estadísticas descriptivas de las columnas numéricas.

# %%
import pandas as pd

# Cargar el dataset del Titanic
df = pd.read_csv("titanic.csv")

# Mostrar las primeras filas del dataset
print("Primeras 5 filas del dataset:")
print(df.head())

# Mostrar información general del dataset (incluye tipos de datos y valores no nulos)
print("\nInformación general del dataset (df.info()):")
df.info()

# Mostrar estadísticas descriptivas (df.describe())
print("\nEstadísticas descriptivas del dataset (df.describe()):")
print(df.describe())
# Out:
# Primeras 5 filas del dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ## Manejo de Valores Faltantes

# %% [markdown]
# Los valores faltantes (NaN, None, etc.) son un problema común en los datasets reales. Pueden ocurrir por diversas razones, como errores en la recolección de datos, información no disponible o fallos en el sistema. Es crucial identificar y manejar estos valores adecuadamente, ya que muchos algoritmos de Machine Learning no pueden trabajar directamente con ellos.
#
# Existen varias estrategias para manejar los valores faltantes:
#
# 1.  **Eliminación:**
#     *   **Eliminar filas:** Si una fila tiene muchos valores faltantes o si el número de filas con valores faltantes es pequeño en comparación con el tamaño total del dataset, se pueden eliminar las filas completas. Sin embargo, esto puede resultar en la pérdida de información valiosa si se eliminan demasiadas filas.
#     *   **Eliminar columnas:** Si una columna tiene un porcentaje muy alto de valores faltantes (ej. > 70-80%), puede ser más sensato eliminar la columna completa, ya que no aportaría mucha información útil.
#
# 2.  **Imputación:** Reemplazar los valores faltantes con un valor estimado. Las técnicas de imputación comunes incluyen:
#     *   **Media/Mediana/Moda:** Reemplazar los valores faltantes con la media (para datos numéricos sin valores atípicos), la mediana (para datos numéricos con valores atípicos) o la moda (para datos categóricos) de la columna.
#     *   **Imputación por regresión:** Utilizar un modelo de regresión para predecir los valores faltantes basándose en otras columnas del dataset.
#     *   **Imputación por k-NN:** Reemplazar los valores faltantes basándose en los valores de los k vecinos más cercanos.
#
# **Ejemplo práctico: Manejo de valores faltantes en el dataset del Titanic**
#
# Primero, identifiquemos la cantidad de valores faltantes por columna:

# %%
# Contar valores faltantes por columna
print("\nValores faltantes por columna:")
print(df.isnull().sum())
# Out:
# Valores faltantes por columna:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Observamos que las columnas `Age`, `Cabin` y `Embarked` tienen valores faltantes. La columna `Cabin` tiene un porcentaje muy alto de valores faltantes, por lo que podríamos considerar eliminarla. Para `Age` y `Embarked`, podemos imputar los valores.

# %%
# Estrategia 1: Eliminar la columna \'Cabin\' debido a la gran cantidad de valores faltantes
df_cleaned = df.drop('Cabin', axis=1)
print("\nDataset después de eliminar la columna Cabin:")
print(df_cleaned.head())

# Estrategia 2: Imputar valores faltantes en \'Age\' con la mediana (más robusta a outliers que la media)
df_cleaned['Age'].fillna(df_cleaned['Age'].median(), inplace=True)
print('\nValores faltantes en Age después de la imputación:')
print(df_cleaned['Age'].isnull().sum())

# Estrategia 3: Imputar valores faltantes en \'Embarked\' con la moda (el puerto de embarque más frecuente)
# Primero, encontramos la moda
most_frequent_embarked = df_cleaned['Embarked'].mode()[0]
df_cleaned['Embarked'].fillna(most_frequent_embarked, inplace=True)
print('\nValores faltantes en Embarked después de la imputación:')
print(df_cleaned['Embarked'].isnull().sum())

# Verificar que no queden valores faltantes (excepto en columnas que no se hayan tocado)
print('\nValores faltantes finales por columna:')
print(df_cleaned.isnull().sum())
# Out:
# Dataset después de eliminar la columna Cabin:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# ...

# %% [markdown]
# ## Manejo de Duplicados

# %% [markdown]
# Los registros duplicados pueden sesgar el análisis y los modelos, ya que dan un peso indebido a ciertas observaciones. Es importante identificarlos y eliminarlos si representan entradas redundantes.

# %%
# Identificar filas duplicadas
duplicates = df_cleaned.duplicated()
print('\nNúmero de filas duplicadas antes de la eliminación:', duplicates.sum())

# Eliminar filas duplicadas
df_cleaned.drop_duplicates(inplace=True)
print('Número de filas duplicadas después de la eliminación:', df_cleaned.duplicated().sum())
print('Forma del dataset después de eliminar duplicados:', df_cleaned.shape)
# Out:
# Número de filas duplicadas antes de la eliminación: 0
# Número de filas duplicadas después de la eliminación: 0
# Forma del dataset después de eliminar duplicados: (891, 11)

# %% [markdown]
# ## Corrección de Tipos de Datos

# %% [markdown]
# Algunas columnas pueden ser cargadas con un tipo de dato incorrecto (ej. números como strings, o categorías como números). Es fundamental asegurar que cada columna tenga el tipo de dato apropiado para el análisis y modelado.

# %% [markdown]
# Con estos pasos, hemos realizado una limpieza básica pero efectiva de nuestro dataset, dejándolo en un estado mucho más adecuado para el análisis exploratorio y la construcción de modelos. La calidad de los datos es la base sobre la que se construye cualquier análisis robusto.

# %%
# Verificar tipos de datos actuales
print('\nTipos de datos actuales:')
print(df_cleaned.dtypes)

# Ejemplo: Si 'Survived' fuera un número pero quisiéramos tratarlo como categoría
# df_cleaned['Survived'] = df_cleaned['Survived'].astype('category')
# print('\nTipo de dato de Survived después de la conversión:')
# print(df_cleaned['Survived'].dtype)

# Para este dataset, los tipos de datos son generalmente correctos para las columnas que usaremos en el análisis.
# Sin embargo, es una buena práctica revisar y ajustar si es necesario.
# Out:
# Tipos de datos actuales:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %% [markdown]
# ## 5. Análisis y Visualización de Datos: Profundizando en las Características

# %% [markdown]
# Una vez que nuestros datos están limpios, el siguiente paso es comprender sus características estadísticas, especialmente la forma de sus distribuciones. Esto nos ayudará a identificar patrones, detectar anomalías y tomar decisiones informadas sobre el preprocesamiento adicional o la selección de modelos. En esta sección, aplicaremos los conceptos de distribución, asimetría, curtosis y desviación estándar a nuestro dataset del Titanic, complementado con diversas visualizaciones.

# %% [markdown]
# ## Medidas Estadísticas Clave

# %% [markdown]
# Revisaremos las medidas de tendencia central y dispersión, y luego nos enfocaremos en la asimetría y curtosis.

# %%
# Medidas de tendencia central y dispersión para columnas numéricas
print("\nMedidas estadísticas clave para columnas numéricas:")
print(df_cleaned[["Age", "Fare", "Pclass", "SibSp", "Parch"]].agg(["mean", "median", "std", "min", "max"]))

# Moda para columnas numéricas (puede haber múltiples modas)
print("\nModa para columnas numéricas:")
for col in ["Age", "Fare", "Pclass", "SibSp", "Parch"]:
    print(f"Moda de {col}: {df_cleaned[col].mode().tolist()}")

# Asimetría (Skewness)
print("\nAsimetría (Skewness):")
print(df_cleaned[["Age", "Fare", "Pclass", "SibSp", "Parch"]].skew())

# Curtosis (Kurtosis)
print("\nCurtosis (Kurtosis):")
print(df_cleaned[["Age", "Fare", "Pclass", "SibSp", "Parch"]].kurtosis())
# Out:
# Medidas estadísticas clave para columnas numéricas:
#               Age        Fare    Pclass     SibSp     Parch
# mean    29.361582   32.204208  2.308642  0.523008  0.381594
# median  28.000000   14.454200  3.000000  0.000000  0.000000
# std     13.019697   49.693429  0.836071  1.102743  0.806057
# min      0.420000    0.000000  1.000000  0.000000  0.000000
# max     80.000000  512.329200  3.000000  8.000000  6.000000
#
# Moda para columnas numéricas:
# Moda de Age: [28.0]
# Moda de Fare: [8.05]
# Moda de Pclass: [3]
# Moda de SibSp: [0]
# Moda de Parch: [0]
#
# Asimetría (Skewness):
# Age       0.510245
# Fare      4.787317
# Pclass   -0.630548
# SibSp     3.695352
# Parch     2.749117
# dtype: float64
#
# Curtosis (Kurtosis):
# Age        0.993871
# Fare      33.398141
# Pclass    -1.280015
# SibSp     17.880420
# Parch      9.778125
# dtype: float64

# %% [markdown]
# **Interpretación:**
#
# *   **Media, Mediana, Moda:** Comparar estos valores nos da una idea de la simetría de la distribución. Si son muy diferentes, sugiere asimetría.
# *   **Desviación Estándar y Rango:** Indican la dispersión de los datos. Una desviación estándar alta significa que los datos están más dispersos alrededor de la media.
# *   **Asimetría:** Valores positivos indican una cola a la derecha (más valores altos), negativos una cola a la izquierda (más valores bajos).
# *   **Curtosis:** Valores positivos indican un pico más pronunciado y colas más pesadas (leptocúrtica), negativos un pico más plano y colas más ligeras (platicúrtica).

# %% [markdown]
# ## Visualización de Distribuciones

# %% [markdown]
# Utilizaremos histogramas, gráficos de caja y bigotes (box plots) y gráficos de violín para visualizar las distribuciones de las columnas numéricas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración para mejorar la visualización
sns.set_style("whitegrid")

# Columnas numéricas para visualización
numeric_cols = ["Age", "Fare", "SibSp", "Parch"]

# Histograma para cada columna numérica
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df_cleaned[col], kde=True, bins=30)
    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# Gráficos de Caja y Bigotes (Box Plots) para cada columna numérica
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(y=df_cleaned[col])
    plt.title(f"Box Plot de {col}")
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# Gráficos de Violín (Violin Plots) para cada columna numérica
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols):
    plt.subplot(2, 2, i + 1)
    sns.violinplot(y=df_cleaned[col])
    plt.title(f"Violin Plot de {col}")
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación de los gráficos:**
#
# *   **Histogramas:** Muestran la forma general de la distribución, la presencia de picos y la asimetría. La curva KDE (Kernel Density Estimate) superpuesta ayuda a visualizar la densidad de probabilidad.
# *   **Gráficos de Caja y Bigotes (Box Plots):** Son excelentes para visualizar la mediana, los cuartiles (Q1 y Q3), el rango intercuartílico (IQR) y la presencia de valores atípicos (outliers). La "caja" representa el 50% central de los datos, y los "bigotes" se extienden hasta 1.5 veces el IQR desde los cuartiles. Los puntos fuera de los bigotes son considerados atípicos.
# *   **Gráficos de Violín (Violin Plots):** Combinan las características de un box plot con una estimación de la densidad de probabilidad (similar a un histograma suavizado). La "forma" del violín muestra la distribución de los datos, siendo más ancha donde hay mayor densidad de puntos. Son útiles para comparar distribuciones entre diferentes categorías o para visualizar la forma de la distribución junto con la mediana y los cuartiles.

# %% [markdown]
# ## Ejercicio Práctico (Python):

# %% [markdown]
# 1.  Elige una columna categórica del dataset (por ejemplo, `Sex` o `Embarked`).
# 2.  Crea un diagrama de barras para visualizar la distribución de esa columna.
# 3.  Crea un box plot o violin plot de una columna numérica (`Age` o `Fare`) agrupado por la columna categórica que elegiste. Interpreta cómo la distribución de la variable numérica cambia entre las categorías.

# %%
# Tu código aquí para el ejercicio
# Ejemplo:
# plt.figure(figsize=(8, 6))
# sns.countplot(x=\'Sex\', data=df_cleaned)
# plt.title(\'Distribución de Pasajeros por Sexo\')
# plt.xlabel(\'Sexo\')
# plt.ylabel(\'Conteo\')
# plt.show()
#
# plt.figure(figsize=(8, 6))
# sns.boxplot(x=\'Sex\', y=\'Age\', data=df_cleaned)
# plt.title(\'Distribución de Edad por Sexo\')
# plt.xlabel(\'Sexo\')
# plt.ylabel(\'Edad\')
# plt.show()

# %% [markdown]
# ## 6. Escalado de Datos: Normalización y Estandarización en la Práctica

# %% [markdown]
# El escalado de datos es un paso crucial para preparar nuestras características numéricas para los algoritmos de Machine Learning. En esta sección, aplicaremos las técnicas de normalización (Min-Max Scaling) y estandarización (Z-score Scaling) a una de las columnas numéricas de nuestro dataset del Titanic y visualizaremos el impacto de estas transformaciones.
#
# Utilizaremos la columna `Fare` (tarifa pagada) para este ejemplo, ya que demostró una fuerte asimetría positiva y una alta curtosis, lo que la convierte en una candidata ideal para observar el efecto del escalado.

# %% [markdown]
# ## Normalización (Min-Max Scaling) con Python

# %% [markdown]
# La normalización Min-Max transforma los datos para que se encuentren en un rango específico, típicamente entre 0 y 1. Esto se logra restando el valor mínimo y dividiendo por el rango (máximo - mínimo).

# %%
from sklearn.preprocessing import MinMaxScaler

# Crear una copia del DataFrame para no modificar el original
df_scaled = df_cleaned.copy()

# Inicializar el MinMaxScaler
min_max_scaler = MinMaxScaler()

# Aplicar la normalización a la columna \'Fare\'
# Reshape(-1, 1) es necesario porque el scaler espera una entrada 2D
df_scaled['Fare_Normalized'] = min_max_scaler.fit_transform(df_scaled[['Fare']])

print("\nPrimeras 5 filas de la columna Fare Normalizada:")
print(df_scaled[['Fare', 'Fare_Normalized']].head())

print("\nEstadísticas descriptivas de Fare Normalizada:")
print(df_scaled['Fare_Normalized'].describe())

# Visualizar la distribución de la tarifa normalizada
plt.figure(figsize=(10, 6))
sns.histplot(df_scaled['Fare_Normalized'], kde=True, bins=50)
plt.title("Distribución de la Tarifa Normalizada (Min-Max Scaling)")
plt.xlabel("Tarifa Normalizada")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Primeras 5 filas de la columna Fare Normalizada:
#       Fare  Fare_Normalized
# 0   7.2500         0.014151
# 1  71.2833         0.139136
# 2   7.9250         0.015469
# 3  53.1000         0.103644
# 4   8.0500         0.015713
#
# Estadísticas descriptivas de Fare Normalizada:
# count    891.000000
# mean       0.062858
# std        0.096995
# min        0.000000
# 25%        0.015440
# 50%        0.028213
# 75%        0.060508
# max        1.000000
# Name: Fare_Normalized, dtype: float64

# %% [markdown]
# **Observaciones:**
#
# *   Los valores de `Fare_Normalized` ahora se encuentran en el rango de 0 a 1.
# *   La forma de la distribución (su asimetría y curtosis) no ha cambiado; la normalización solo cambia la escala de los datos, no su forma.

# %% [markdown]
# ## Estandarización (Z-score Scaling) con Python

# %% [markdown]
# La estandarización (Z-score Scaling) transforma los datos para que tengan una media de 0 y una desviación estándar de 1. Esto es útil para algoritmos que asumen una distribución normal o son sensibles a la varianza.

# %%
from sklearn.preprocessing import StandardScaler

# Crear una copia del DataFrame para no modificar el original
df_scaled_std = df_cleaned.copy()

# Inicializar el StandardScaler
standard_scaler = StandardScaler()

# Aplicar la estandarización a la columna \'Fare\'
df_scaled_std['Fare_Standardized'] = standard_scaler.fit_transform(df_scaled_std[['Fare']])

print("\nPrimeras 5 filas de la columna Fare Estandarizada:")
print(df_scaled_std[['Fare', 'Fare_Standardized']].head())

print("\nEstadísticas descriptivas de Fare Estandarizada:")
print(df_scaled_std['Fare_Standardized'].describe())

# Visualizar la distribución de la tarifa estandarizada
plt.figure(figsize=(10, 6))
sns.histplot(df_scaled_std['Fare_Standardized'], kde=True, bins=50)
plt.title("Distribución de la Tarifa Estandarizada (Z-score Scaling)")
plt.xlabel("Tarifa Estandarizada")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Primeras 5 filas de la columna Fare Estandarizada:
#       Fare  Fare_Standardized
# 0   7.2500          -0.502445
# 1  71.2833           0.786845
# 2   7.9250          -0.488854
# 3  53.1000           0.420730
# 4   8.0500          -0.486337
#
# Estadísticas descriptivas de Fare Estandarizada:
# count    8.910000e+02
# mean     3.987333e-18
# std      1.000562e+00
# min     -6.484217e-01
# 25%     -4.891482e-01
# 50%     -3.573909e-01
# 75%     -2.424635e-02
# max      9.667167e+00
# Name: Fare_Standardized, dtype: float64

# %% [markdown]
# **Observaciones:**
#
# *   Los valores de `Fare_Standardized` ahora tienen una media cercana a 0 y una desviación estándar cercana a 1.
# *   Al igual que con la normalización, la forma de la distribución no ha cambiado. La estandarización reescala los datos manteniendo su forma original.

# %% [markdown]
# ## Comparación Visual de las Transformaciones

# %% [markdown]
# Para apreciar mejor el efecto de ambas transformaciones, podemos visualizar las distribuciones originales, normalizadas y estandarizadas en un mismo gráfico o en gráficos adyacentes.

# %%
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
sns.histplot(df_cleaned['Fare'], kde=True, bins=50)
plt.title("Original Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Frequency")

plt.subplot(1, 3, 2)
sns.histplot(df_scaled['Fare_Normalized'], kde=True, bins=50)
plt.title("Normalized Fare Distribution (Min-Max)")
plt.xlabel("Normalized Fare")
plt.ylabel("Frequency")

plt.subplot(1, 3, 3)
sns.histplot(df_scaled_std['Fare_Standardized'], kde=True, bins=50)
plt.title("Standardized Fare Distribution (Z-score)")
plt.xlabel("Standardized Fare")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ejercicio Práctico (Python):

# %% [markdown]
# 1.  Selecciona la columna `Age` del dataset `df_cleaned`.
# 2.  Aplica tanto la normalización Min-Max como la estandarización Z-score a esta columna.
# 3.  Muestra las primeras filas de las nuevas columnas transformadas.
# 4.  Calcula las estadísticas descriptivas (media, desviación estándar, min, max) para ambas columnas transformadas y verifica que los resultados sean los esperados.
# 5.  Crea histogramas para visualizar la distribución de la `Age` original, normalizada y estandarizada, y compara sus formas y rangos.

# %%
# Tu código aquí para el ejercicio
# Ejemplo:
# df_age_scaled = df_cleaned.copy()
# min_max_scaler_age = MinMaxScaler()
# df_age_scaled[\'Age_Normalized\'] = min_max_scaler_age.fit_transform(df_age_scaled[[\'Age\']])
# standard_scaler_age = StandardScaler()
# df_age_scaled[\'Age_Standardized\'] = standard_scaler_age.fit_transform(df_age_scaled[[\'Age\']])
# print(df_age_scaled[[\'Age\', \'Age_Normalized\', \'Age_Standardized\']].head())
# print(df_age_scaled[[\'Age_Normalized\', \'Age_Standardized\']].describe())
# plt.figure(figsize=(18, 6))
# plt.subplot(1, 3, 1)
# sns.histplot(df_age_scaled[\'Age\'], kde=True, bins=30)
# plt.title(\'Original Age Distribution\')
# plt.subplot(1, 3, 2)
# sns.histplot(df_age_scaled[\'Age_Normalized\'], kde=True, bins=30)
# plt.title(\'Normalized Age Distribution\')
# plt.subplot(1, 3, 3)
# sns.histplot(df_age_scaled[\'Age_Standardized\'], kde=True, bins=30)
# plt.title(\'Standardized Age Distribution\')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# La elección entre normalización y estandarización dependerá de las características específicas de tu dataset y de los requisitos del algoritmo de Machine Learning que vayas a utilizar. Es fundamental comprender cómo cada técnica afecta tus datos para tomar la decisión más informada.

# %% [markdown]
# ## 7. Integración de Código en R y Ejercicios Complementarios

# %% [markdown]
# Google Colab es una plataforma versátil que no solo soporta Python, sino también R. Esto nos permite aprovechar las fortalezas de ambos lenguajes en un mismo entorno. En esta sección, replicaremos algunos de los pasos de limpieza de datos, análisis de distribución, asimetría, curtosis, normalización y estandarización utilizando R, para ofrecer una perspectiva diferente y complementar los ejemplos en Python.

# %% [markdown]
# ## Configuración de R en Google Colab

# %% [markdown]
# Para usar R en un cuaderno de Colab, simplemente necesitas cambiar el entorno de ejecución. Ve a `Entorno de ejecución > Cambiar tipo de entorno de ejecución` y selecciona `R` en el desplegable `Tipo de entorno de ejecución`. Una vez hecho esto, las celdas de código se ejecutarán como código R.
#
# **Nota:** Para este cuaderno, mantendremos el entorno de ejecución en Python y usaremos la extensión `%%R` para ejecutar bloques de código R dentro de celdas de Python. Esto es útil si deseas combinar ambos lenguajes en un solo cuaderno.

# %% [markdown]
# ## Carga del Dataset y Exploración Inicial en R

# %% [markdown]
# Primero, cargaremos el dataset del Titanic en R y realizaremos una exploración inicial. Necesitaremos instalar y cargar la librería `readr` para leer archivos CSV.

# %%
# Instalar y cargar la librería readr si no está instalada
if (!require(readr)) {
  install.packages("readr")
  library(readr)
}

# Cargar el dataset del Titanic
df_r <- read_csv("titanic.csv")

# Mostrar las primeras filas del dataset
cat("Primeras 5 filas del dataset en R:\n")
print(head(df_r))

# Mostrar la estructura del dataset
cat("\nEstructura del dataset en R:\n")
print(str(df_r))

# Mostrar un resumen estadístico
cat("\nResumen estadístico del dataset en R:\n")
print(summary(df_r))

# %% [markdown]
# ## Manejo de Valores Faltantes en R

# %% [markdown]
# En R, el manejo de valores faltantes (`NA`) es similar al de Python. Identificaremos y trataremos los valores faltantes en las columnas `Age`, `Cabin` y `Embarked`.

# %%
# Contar valores faltantes por columna
cat("\nValores faltantes por columna en R:\n")
print(colSums(is.na(df_r)))

# Estrategia 1: Eliminar la columna \'Cabin\'
df_r_cleaned <- subset(df_r, select = -c(Cabin))
cat("\nDataset después de eliminar la columna Cabin en R:\n")
print(head(df_r_cleaned))

# Estrategia 2: Imputar valores faltantes en \'Age\' con la mediana
df_r_cleaned$Age[is.na(df_r_cleaned$Age)] <- median(df_r_cleaned$Age, na.rm = TRUE)
cat("\nValores faltantes en Age después de la imputación en R:\n")
print(sum(is.na(df_r_cleaned$Age)))

# Estrategia 3: Imputar valores faltantes en \'Embarked\' con la moda
# La moda en R para factores se puede encontrar con table y which.max
mode_embarked <- names(which.max(table(df_r_cleaned$Embarked)))
df_r_cleaned$Embarked[is.na(df_r_cleaned$Embarked)] <- mode_embarked
cat("\nValores faltantes en Embarked después de la imputación en R:\n")
print(sum(is.na(df_r_cleaned$Embarked)))

# Verificar que no queden valores faltantes
cat("\nValores faltantes finales por columna en R:\n")
print(colSums(is.na(df_r_cleaned)))

# %% [markdown]
# ## Análisis de Distribución, Asimetría y Curtosis en R

# %% [markdown]
# Para calcular la asimetría y la curtosis en R, a menudo se utiliza el paquete `e1071`. Visualizaremos las distribuciones con histogramas.

# %%
# Instalar y cargar la librería e1071 si no está instalada
if (!require(e1071)) {
  install.packages("e1071")
  library(e1071)
}

# Histograma de la Edad
hist(df_r_cleaned$Age, main="Distribución de la Edad de los Pasajeros (R)",
     xlab="Edad", ylab="Frecuencia", col="skyblue", border="black")

# Histograma de la Tarifa
hist(df_r_cleaned$Fare, main="Distribución de la Tarifa Pagada (R)",
     xlab="Tarifa", ylab="Frecuencia", col="lightgreen", border="black")

# Calcular la asimetría
cat("\nAsimetría (Skewness) en R:\n")
print(skewness(df_r_cleaned$Age))
print(skewness(df_r_cleaned$Fare))

# Calcular la curtosis
cat("\nCurtosis (Kurtosis) en R:\n")
print(kurtosis(df_r_cleaned$Age))
print(kurtosis(df_r_cleaned$Fare))

# %% [markdown]
# ## Normalización y Estandarización en R

# %% [markdown]
# En R, podemos realizar normalización y estandarización utilizando funciones base o paquetes como `caret`.

# %%
# Normalización (Min-Max Scaling) para Fare
min_val <- min(df_r_cleaned$Fare)
max_val <- max(df_r_cleaned$Fare)
df_r_cleaned$Fare_Normalized <- (df_r_cleaned$Fare - min_val) / (max_val - min_val)

cat("\nPrimeras 5 filas de la columna Fare Normalizada en R:\n")
print(head(df_r_cleaned[, c("Fare", "Fare_Normalized")]))

# Estandarización (Z-score Scaling) para Fare
mean_val <- mean(df_r_cleaned$Fare)
sd_val <- sd(df_r_cleaned$Fare)
df_r_cleaned$Fare_Standardized <- (df_r_cleaned$Fare - mean_val) / sd_val

cat("\nPrimeras 5 filas de la columna Fare Estandarizada en R:\n")
print(head(df_r_cleaned[, c("Fare", "Fare_Standardized")]))

# Visualizar las distribuciones transformadas en R
par(mfrow=c(1, 2)) # Configurar para 1 fila, 2 columnas de gráficos
hist(df_r_cleaned$Fare_Normalized, main="Tarifa Normalizada (R)", xlab="", col="lightblue", border="black")
hist(df_r_cleaned$Fare_Standardized, main="Tarifa Estandarizada (R)", xlab="", col="lightcoral", border="black")

# %% [markdown]
# ## Ejercicio Práctico (R):

# %% [markdown]
# 1.  Selecciona la columna `Age` del dataset `df_r_cleaned`.
# 2.  Aplica tanto la normalización Min-Max como la estandarización Z-score a esta columna en R.
# 3.  Muestra las primeras filas de las nuevas columnas transformadas.
# 4.  Calcula las estadísticas descriptivas (media, desviación estándar, min, max) para ambas columnas transformadas y verifica que los resultados sean los esperados.
# 5.  Crea histogramas para visualizar la distribución de la `Age` original, normalizada y estandarizada en R, y compara sus formas y rangos.

# %%
# Tu código aquí para el ejercicio en R
# Ejemplo:
# min_val_age <- min(df_r_cleaned$Age)
# max_val_age <- max(df_r_cleaned$Age)
# df_r_cleaned$Age_Normalized <- (df_r_cleaned$Age - min_val_age) / (max_val_age - min_val_age)
#
# mean_val_age <- mean(df_r_cleaned$Age)
# sd_val_age <- sd(df_r_cleaned$Age)
# df_r_cleaned$Age_Standardized <- (df_r_cleaned$Age - mean_val_age) / sd_val_age
#
# cat("\nPrimeras 5 filas de la columna Age Normalizada y Estandarizada en R:\n")
# print(head(df_r_cleaned[, c("Age", "Age_Normalized", "Age_Standardized")]))
#
# par(mfrow=c(1, 2))
# hist(df_r_cleaned$Age_Normalized, main="Edad Normalizada (R)", xlab="", col="lightblue", border="black")
# hist(df_r_cleaned$Age_Standardized, main="Edad Estandarizada (R)", xlab="", col="lightcoral", border="black")

# %% [markdown]
# Esta sección demuestra cómo las mismas tareas de preprocesamiento y análisis pueden realizarse en R, proporcionando flexibilidad y opciones para los científicos de datos que trabajan con ambos lenguajes. La elección entre Python y R a menudo se reduce a la preferencia personal, la disponibilidad de librerías específicas o los requisitos del proyecto.
